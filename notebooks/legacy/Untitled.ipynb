# %%
# !mamba install -c conda-forge numpy pandas scikit-learn tqdm ipykernel -y
# Out:
# 'mamba' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !conda install -c conda-forge numpy pandas scikit-learn tqdm ipykernel -y
# Out:
# ^C

# %%
# !conda install -c conda-forge numpy pandas scikit-learn tqdm ipykernel -y
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !python -m ipykernel install --user --name firesight --display-name "FireSight-IR"
# Out:
# Installed kernelspec firesight in C:\Users\taylo\AppData\Roaming\jupyter\kernels\firesight
